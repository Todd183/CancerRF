# %%
using Plots, DataFrames, CSV

# Path of correlation data
cor_incidence_path = "data/correlation_result/cor_incidence.csv"
cor_mortality_path = "data/correlation_result/cor_mortality.csv"
cor_incidence_children_path = "data/correlation_result/cor_incidence_children.csv"

# Load data from data_path
cor_incidence = CSV.File(cor_incidence_path) |> DataFrame
cor_mortality = CSV.File(cor_mortality_path) |> DataFrame
cor_incidence_children = CSV.File(cor_incidence_children_path) |> DataFrame
# Out:
# 120×7 DataFrame
#  Row │ p_pearson  p_adjusted  cor         cancer      feature                  ⋯
#      │ Float64    Float64     Float64     String      String                   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.369941    1.0         0.145622   Breast      Children-One child       ⋯
#    2 │ 0.742131    1.0        -0.0536896  Breast      Children-Two children
#    3 │ 0.463802    1.0        -0.1192     Breast      Children-Three children
#    4 │ 0.511648    1.0        -0.106857   Breast      Children-Four children
#    5 │ 0.918006    1.0         0.016809   Breast      Children-Five children   ⋯
#    6 │ 0.812919    1.0         0.0386305  Breast      Children-Six or more chi
#    7 │ 0.582475    1.0        -0.0895926  Breast      Children-> 0 children
#    8 │ 0.5129      1.0        -0.106542   Breast      Children-> 1 children
#    9 │ 0.527396    1.0        -0.102923   Breast      Children-> 2 children    ⋯
#   10 │ 0.615282    1.0        -0.0819238  Breast      Children-> 3 children
#   11 │ 0.740615    1.0        -0.0540166  Breast      Children-> 4 children
#   ⋮  │     ⋮          ⋮           ⋮           ⋮                     ⋮          ⋱
#  111 │ 0.032878    0.394536   -0.338064   Uterine     Children-Three children
#  112 │ 0.24166     1.0        -0.189452   Uterine     Children-Four children   ⋯
#  113 │ 0.708606    1.0         0.0609701  Uterine     Children-Five children
#  114 │ 0.168123    1.0         0.222233   Uterine     Children-Six or more chi
#  115 │ 0.159252    1.0        -0.226839   Uterine     Children-> 0 children
#  116 │ 0.106266    0.956396   -0.259219   Uterine     Children-> 1 children    ⋯
#  117 │ 0.240402    1.0        -0.18995    Uterine     Children-> 2 children
#  118 │ 0.688865    1.0        -0.0653115  Uterine     Children-> 3 children
#  119 │ 0.753219    1.0         0.0513048  Uterine     Children-> 4 children
#  120 │ 0.790701    1.0         0.0433175  Uterine     Children-> 5 children    ⋯
#                                                    3 columns and 99 rows omitted

# %%
# Correlation Coefficient and P_value in each feature and cancer. X-axis is coefficient, and y-axis is logarithmized p-value - 
# the bigger in y-value means the higher correlation. The dashed line means how we select significant features in particular cancer.
scatter(cor_incidence.cor, -log10.(cor_incidence.p_adjusted), group=cor_incidence.cancer, xlabel="cor", ylabel="-log(p_adjusted)", title="Coefficient and P_value in Incidence",
markershape=:circle, markerstrokewidth=0, alpha=0.4, markerstrokealpha=0, size=(650, 400), legend=:outertopright)
hline!([2], color=:gray, linestyle=:dash, label="y=2")  # 水平虚线
vline!([0.2, -0.2], color=:gray, linestyle=:dash, label="x=0.2, x=-0.2")  # 垂直虚线

# %%
scatter(cor_mortality.cor, -log10.(cor_mortality.p_adjusted), group=cor_mortality.cancer, xlabel="cor", ylabel="-log(p_adjusted)", title="Coefficient and P_value in Mortality",
markershape=:circle, markerstrokewidth=0, alpha=0.4, markerstrokealpha=0, size=(650, 400), legend=:outertopright)
hline!([2], color=:gray, linestyle=:dash, label="y=2")  # 水平虚线
vline!([0.2, -0.2], color=:gray, linestyle=:dash, label="x=0.2, x=-0.2")  # 垂直虚线

# %%
scatter(cor_incidence_children.cor, -log10.(cor_incidence_children.p_adjusted), group=cor_incidence_children.cancer, xlabel="cor", ylabel="-log(p_adjusted)", title="Coefficient and P_value in Children Fatures",
markershape=:circle, markerstrokewidth=0, alpha=0.4, markerstrokealpha=0, size=(650, 400), legend=:outertopright)
hline!([2], color=:gray, linestyle=:dash, label="y=2")  # 水平虚线
vline!([0.2, -0.2], color=:gray, linestyle=:dash, label="x=0.2, x=-0.2")  # 垂直虚线
